# %%
import sys
sys.path.append('/mnt/home/larend/kfx')
from kfx.load import load_lfp

# %%
import pandas as pd

# %%
rec = pd.read_csv('/mnt/home/larend/kfx/ref/recordings.csv').loc[10]

# %%
offset = int(rec.lfp_start * 30000 / 2500)
chans = range(int(rec.theta_start * 2), int(rec.theta_end * 2))

# %%
root = '/mnt/home/larend/ceph/data/kfx/2022-08-15/'
file = '2022-08-15-02-25-00_M018_RSK_mPFC_HPC_3_10_30mpk_g0_t0.imec1.ap.bin'
path = root + file

# %%
lfp = load_lfp(path, startmin=75 + 20/60, endmin=75 + 21/60, offset=offset, channels=chans)

# %%
lfp.head()
# Out:
# channel           80        81        82        83        84        85   \
# time
# 4520.000000 -0.001266 -0.000375 -0.000164  0.000258 -0.000539 -0.000258
# 4520.000033 -0.000937 -0.000398  0.000492  0.000422 -0.000539 -0.000281
# 4520.000067 -0.000891 -0.000164  0.000469  0.000445 -0.000352 -0.000281
# 4520.000100 -0.000656  0.000188  0.000727  0.000633 -0.000141 -0.000258
# 4520.000133 -0.000492  0.000352  0.000844  0.000656  0.000070 -0.000094
#
# channel           86        87        88        89   ...       210       211  \
# time                                                 ...
# 4520.000000 -0.000891  0.000117 -0.000492  0.000164  ...  0.000727 -0.000937
# 4520.000033 -0.000609  0.000141 -0.000352  0.000141  ...  0.000797 -0.000797
# 4520.000067 -0.000539  0.000141 -0.000305  0.000328  ...  0.000891 -0.000797
# 4520.000100 -0.000492  0.000398 -0.000258  0.000352  ...  0.000867 -0.000586
# 4520.000133 -0.000305  0.000469 -0.000188  0.000516  ...  0.000844 -0.000516
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
plt.figure()
for i in range(3):
    y = lfp[80 + i].iloc[:1000] - 0.004 * i
    x = np.arange(1000) / 30000
    plt.plot(x, y, 'k')
plt.show()
