# %%
# %load_ext autoreload
# %autoreload 2

# %%
import re
import os
import pandas as pd
import numpy as np

if os.name == 'posix':
    import pathlib
    pathlib.WindowsPath = pathlib.PosixPath

from src import paths

# %%
pfcpaths = pd.read_pickle(f'{paths.REF}/PFC_lfp_paths.file')
hpcpaths = pd.read_pickle(f'{paths.REF}/HPC_lfp_paths.file')

# %%
for pfcpath, hpcpath in zip(pfcpaths, hpcpaths):
    assert str(pfcpath).replace('imec0', 'imec1') == str(hpcpath)

# %% [markdown]
# PFC paths and HPC paths are all exactly identical, except that PFC contains the substring `imec0` and HPC contains substring `imec1`. These are the identifiers for the two NeuroPixels probes used.

# %%
from datetime import datetime

def sessinfo(hpcpath):
    probedir, file = os.path.split(hpcpath)
    sessdir, probedir = os.path.split(probedir)
    _, sessdir = os.path.split(sessdir)
    indiv = re.search(r'(M\d{3})_', sessdir)[1]
    drug = re.search(r'_([a-zA-Z0-9-]*)_[m]*PFC', sessdir)[1]
    doses = re.search(r'HPC_([\w]*mpk)', sessdir)[1]
    doses = tuple(int(n) for n in doses.strip('mpk').split('_'))
    date = re.search(r'(2022-\d{2}-\d{2})', sessdir)[1]
    date = datetime.fromisoformat(date)
    path = os.path.join(sessdir, probedir.replace('_imec1', ''))
    return {
        'indiv': indiv,
        'date': date,
        'drug': drug,
        'doses': doses,
        'path': path,
    }

# %%
df = pd.DataFrame([sessinfo(path) for path in hpcpaths])
assert np.all(df == df.sort_values('date'))

# %% [markdown]
# The `sessnum` in Gino's code is an index going from 0 to 35 in order of session recording date.

# %%
df.index.name = 'recording'
df.head()
# Out:
#           indiv       date drug        doses  \
# recording
# 0          M015 2022-07-27  SAL    (0, 0, 0)
# 1          M016 2022-07-28  SAL    (0, 0, 0)
# 2          M015 2022-08-01  RSK  (3, 10, 30)
# 3          M015 2022-08-03  RSK  (3, 10, 30)
# 4          M016 2022-08-04  RSK  (3, 10, 30)
#
#                                                         path
# recording
# 0          2022-07-27-07-41-00_M015_SAL_PFC_HPC_0_0_0mpk/...
# 1          2022-07-28-13-19-00_M016_SAL_PFC_HPC_0_0_0mpk/...
# 2          2022-08-01_04-30-00_M015_RSK_mPFC_HPC_3_10_30m...
# 3          2022-08-03_12-45-00_M015_RSK_mPFC_HPC_3_10_30m...
# 4          2022-08-04_03-45-00_M016_RSK_mPFC_HPC_3_10_30m...

# %%
df.to_csv(f'{paths.REF}/sessions.csv')

# %%
pd.read_csv(f'{paths.REF}/sessions.csv')
# Out:
#     recording indiv        date        drug           doses  \
# 0           0  M015  2022-07-27         SAL       (0, 0, 0)
# 1           1  M016  2022-07-28         SAL       (0, 0, 0)
# 2           2  M015  2022-08-01         RSK     (3, 10, 30)
# 3           3  M015  2022-08-03         RSK     (3, 10, 30)
# 4           4  M016  2022-08-04         RSK     (3, 10, 30)
# 5           5  M016  2022-08-06         RSK     (3, 10, 30)
# 6           6  M017  2022-08-08         SAL       (0, 0, 0)
# 7           7  M018  2022-08-11         SAL       (0, 0, 0)
# 8           8  M017  2022-08-12         RSK     (3, 10, 30)
# 9           9  M018  2022-08-13         RSK     (3, 10, 30)
# 10         10  M018  2022-08-15         RSK     (3, 10, 30)
# 11         11  M020  2022-08-18        1020  (1, 3, 10, 30)
# 12         12  M019  2022-08-19        1020  (1, 3, 10, 30)
# 13         13  M021  2022-09-06        1020  (1, 3, 10, 30)
# 14         14  M022  2022-09-07        1020  (1, 3, 10, 30)
# 15         15  M023  2022-09-12         SAL       (0, 0, 0)
# 16         16  M023  2022-09-14         RSK     (3, 10, 30)
# 17         17  M023  2022-09-16         RSK     (3, 10, 30)
# 18         18  M024  2022-09-21  R-ketamine  (1, 3, 10, 30)
# 19         19  M025  2022-09-22  S-ketamine  (1, 3, 10, 30)
# 20         20  M026  2022-09-23  R-ketamine  (1, 3, 10, 30)
# 21         21  M027  2022-09-24  S-ketamine  (1, 3, 10, 30)
# 22         22  M024  2022-09-29  R-ketamine  (1, 3, 10, 30)
# 23         23  M025  2022-10-03  S-ketamine  (1, 3, 10, 30)
# 24         24  M027  2022-10-05  S-ketamine  (1, 3, 10, 30)
# 25         25  M026  2022-10-06  R-ketamine  (1, 3, 10, 30)
# 26         26  M028  2022-10-13    CP101606  (1, 3, 10, 30)
# 27         27  M029  2022-10-14    CP101606  (1, 3, 10, 30)
# 28         28  M030  2022-10-18         PCP      (1, 3, 10)
# 29         29  M031  2022-10-19         PCP      (1, 3, 10)
# 30         30  M028  2022-10-20    CP101606  (1, 3, 10, 30)
# 31         31  M029  2022-10-21    CP101606  (1, 3, 10, 30)
# 32         32  M030  2022-10-24         PCP      (1, 3, 10)
# 33         33  M031  2022-10-25         PCP      (1, 3, 10)
# 34         34  M032  2022-10-27    CP101606  (1, 3, 10, 30)
# 35         35  M033  2022-10-28    CP101606  (1, 3, 10, 30)
#
#                                                  path
# 0   2022-07-27-07-41-00_M015_SAL_PFC_HPC_0_0_0mpk/...
# 1   2022-07-28-13-19-00_M016_SAL_PFC_HPC_0_0_0mpk/...
# 2   2022-08-01_04-30-00_M015_RSK_mPFC_HPC_3_10_30m...
# 3   2022-08-03_12-45-00_M015_RSK_mPFC_HPC_3_10_30m...
